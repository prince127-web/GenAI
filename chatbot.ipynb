# %% [markdown]
# <a href="https://colab.research.google.com/github/prince127-web/GenAI/blob/main/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 25.6 MB/s eta 0:00:00

# %%
# !pip install -U langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 5.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.18
#     Uninstalling langchain-1.3.18:
#       Successfully uninstalled langchain-1.3.18
# ...

# %%
from openai import OpenAI
from google.colab import userdata

api_key = userdata.get("openai")

client = OpenAI(api_key=api_key)

prompt_text = "Latest Open AI Model that recently released ?"

response = client.responses.create(
    model="gpt-5.6-luna",
    input=prompt_text
)

print(response.output_text)
# Out:
# The most recently released major OpenAI model is **GPT‑5**, introduced in **August 2025**. It is designed for stronger reasoning, coding, writing, and multimodal tasks.
#
# If you mean the latest model before GPT‑5, OpenAI released the **GPT‑4.1 family**—including **GPT‑4.1, GPT‑4.1 mini, and GPT‑4.1 nano**—in April 2025.
